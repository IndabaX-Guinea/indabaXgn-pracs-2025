# %% [markdown]
# # Practical 4: Advanced Topics in Deep Learning
#
# Explore transfer learning, attention mechanisms, and transformers.
#
# ## Table of Contents
# 1. [Transfer Learning](#transfer)
# 2. [Fine-tuning Pre-trained Models](#finetune)
# 3. [Attention Mechanisms](#attention)
# 4. [Introduction to Transformers](#transformers)

# %%
import torch
import torch.nn as nn
from torchvision import models
from transformers import AutoModel, AutoTokenizer
import sys
sys.path.append('..')
from utils.helper_functions import *

set_seed(42)
device = get_device()

# %% [markdown]
# ## Exercise 4.1: Transfer Learning with ResNet
#
# Use a pre-trained ResNet for feature extraction.

# %%
# TODO: Load pre-trained ResNet
# Freeze layers
# Replace final layer for your task

resnet = models.resnet18(pretrained=True)
# TODO: Modify for your task

# %% [markdown]
# ## Exercise 4.2: Fine-tuning Strategy

# %%
# TODO: Implement gradual unfreezing
# TODO: Use different learning rates for different layers

# %% [markdown]
# ## Exercise 4.3: Self-Attention Mechanism

# %%
class SelfAttention(nn.Module):
    def __init__(self, embed_dim):
        super(SelfAttention, self).__init__()
        # TODO: Implement Q, K, V projections
        pass
    
    def forward(self, x):
        # TODO: Implement attention computation
        pass

# %% [markdown]
# ## Exercise 4.4: Using Hugging Face Transformers

# %%
# TODO: Load a pre-trained transformer model
# Example: BERT for text classification

# model = AutoModel.from_pretrained('bert-base-uncased')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
