# %% [markdown]
# # Practical 3: Recurrent Neural Networks (RNNs)
#
# Learn about sequential data processing with RNNs, LSTMs, and GRUs.
#
# ## Table of Contents
# 1. [Setup and Imports](#setup)
# 2. [Understanding RNNs](#rnns)
# 3. [Text Processing](#text)
# 4. [Building LSTMs](#lstm)
# 5. [Applications](#applications)

# %%
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence
import sys
sys.path.append('..')
from utils.helper_functions import *

set_seed(42)
device = get_device()

# %% [markdown]
# ## Exercise 3.1: Simple RNN
#
# Build a basic RNN for sequence classification.

# %%
class SimpleRNN(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, output_dim):
        super(SimpleRNN, self).__init__()
        # TODO: Implement RNN layers
        pass
    
    def forward(self, x):
        # TODO: Implement forward pass
        pass

# %% [markdown]
# ## Exercise 3.2: LSTM for Sentiment Analysis

# %%
class SentimentLSTM(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, output_dim):
        super(SentimentLSTM, self).__init__()
        # TODO: Implement LSTM layers
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x):
        # TODO: Implement forward pass
        pass

# %% [markdown]
# ## Exercise 3.3: Text Generation
#
# Use an RNN to generate text character by character.

# %%
# TODO: Implement character-level text generation
