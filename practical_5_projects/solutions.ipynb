# %% [markdown]
# # Practical 5: Projects - Example Solution
#
# This is an example project solution. Your solution will depend on your chosen project.

# %% [markdown]
# ## Example Project: Image Classification on Custom Dataset
#
# This example shows how to complete a project using transfer learning.

# %%
# See the project README for guidance on completing your own project
