# %% [markdown]
# # Practical 5: Deep Learning Projects
#
# Apply everything you've learned to a real-world project!
#
# ## Project Template
#
# This notebook provides a template for your final project.
#
# ### Sections to Complete:
# 1. Problem Definition
# 2. Data Exploration
# 3. Model Architecture
# 4. Training
# 5. Evaluation
# 6. Conclusions

# %%
import torch
import torch.nn as nn
import sys
sys.path.append('..')
from utils.helper_functions import *

set_seed(42)
device = get_device()

# %% [markdown]
# ## 1. Problem Definition
#
# **TODO:** Describe your project:
# - What problem are you solving?
# - Why is it important?
# - What is your success metric?

# %% [markdown]
# ## 2. Data Exploration
#
# **TODO:** Load and explore your dataset:
# - Show sample data
# - Visualize distributions
# - Identify potential issues

# %%
# TODO: Load your dataset
# TODO: Visualize samples
# TODO: Check for class imbalance, missing values, etc.

# %% [markdown]
# ## 3. Model Architecture
#
# **TODO:** Design your model:
# - Justify your architecture choice
# - Implement the model
# - Show model summary

# %%
class YourModel(nn.Module):
    def __init__(self):
        super(YourModel, self).__init__()
        # TODO: Define your architecture
        pass
    
    def forward(self, x):
        # TODO: Implement forward pass
        pass

# %% [markdown]
# ## 4. Training
#
# **TODO:** Train your model:
# - Set up training loop
# - Track metrics
# - Save best model

# %%
# TODO: Implement training
# Use helper functions from utils

# %% [markdown]
# ## 5. Evaluation
#
# **TODO:** Evaluate your model:
# - Test set performance
# - Confusion matrix
# - Error analysis

# %%
# TODO: Evaluate model
# TODO: Visualize results
# TODO: Analyze errors

# %% [markdown]
# ## 6. Conclusions
#
# **TODO:** Summarize your findings:
# - What worked well?
# - What didn't work?
# - What would you do differently?
# - Future improvements?

# %% [markdown]
# ## Congratulations! 🎉
#
# You've completed the Deep Learning IndabaX Guinea Practicals 2025!
