# %% [markdown]
# # Practical 2: Convolutional Neural Networks (CNNs)
#
# Welcome to Practical 2! In this session, you will learn about CNNs for image processing.
#
# ## Table of Contents
# 1. [Setup and Imports](#setup)
# 2. [Understanding Convolutions](#convolutions)
# 3. [Building CNNs](#building)
# 4. [Training on CIFAR-10](#cifar10)
# 5. [Data Augmentation](#augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from utils.helper_functions import *

set_seed(42)
device = get_device()
print(f"Using device: {device}")

# %% [markdown]
# ## Exercise 2.1: Build a Simple CNN
#
# TODO: Implement a CNN with:
# - 2 convolutional layers
# - Max pooling
# - 2 fully connected layers

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        # TODO: Define convolutional and fully connected layers
        pass
    
    def forward(self, x):
        # TODO: Implement forward pass
        pass

# %% [markdown]
# ## Load CIFAR-10 Dataset

# %%
# TODO: Load CIFAR-10 with appropriate transforms
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = datasets.CIFAR10('../data', train=True, download=True, transform=transform_train)
test_dataset = datasets.CIFAR10('../data', train=False, download=True, transform=transform_train)

# %% [markdown]
# ## Exercise 2.2: Implement Data Augmentation
#
# Add random flips, crops, and color jitter to improve generalization.

# %%
# TODO: Create augmented transform
transform_augmented = transforms.Compose([
    # Add augmentation transforms here
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %% [markdown]
# ## More exercises to come...
#
# Complete the TODOs above and experiment with different architectures!
